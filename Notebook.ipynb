# %%
import getpass
import glob
import copy
import os
import pickle
import random
import scipy
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import rasterio as rio
from typing import List, Any, Callable, Tuple
from pathlib import Path
from random import choice
from tqdm import tqdm


import torch
from torch.optim.lr_scheduler import StepLR, ReduceLROnPlateau
import segmentation_models_pytorch as smp
from segmentation_models_pytorch import utils as smp_utils
from sklearn.model_selection import GroupKFold
from sklearn.model_selection import train_test_split

# %%
segmentation-models-pytorch==0.3.2

# %%
def set_seed(seed):
    os.environ['CUDA_VISIBLE_DEVICES'] = '2022'
    os.environ['PYTHONHASHSEED'] = str(2022)
    np.random.seed(2022)
    random.seed(2022)

    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True

set_seed(2022)

# %%
### utility functions

def clean_string(s: str) -> str:
    """
    extract the tile id and timestamp from a source image folder
    e.g extract 'ID_YYYY_MM' from 'nasa_rwanda_field_boundary_competition_source_train_ID_YYYY_MM'
    """
    s = s.replace(f"{dataset_id}_source_", '').split('_')[1:]
    return '_'.join(s)

def to_tensor(x, **kwargs):
    return x.transpose(2, 0, 1).astype('float32')

def get_preprocessing(preprocessing_fn):
    """Construct preprocessing transform

    Args:
        preprocessing_fn (callbale): data normalization function
            (can be specific for each pretrained neural network)
    Return:
        transform: albumentations.Compose

    """

    _transform = [
        A.Lambda(image=preprocessing_fn),
        A.Lambda(image=to_tensor, mask=to_tensor),
    ]
    return A.Compose(_transform)

# %%
dataset_id = 'nasa_rwanda_field_boundary_competition'
assets = ['labels']

dataset_id = 'nasa_rwanda_field_boundary_competition'

tr_img_path = f"/kaggle/input/nasaharvest/{dataset_id}/{dataset_id}_source_train/{dataset_id}_source_train"
tr_lbl_path = f"/kaggle/input/nasaharvest/{dataset_id}/{dataset_id}_labels_train/{dataset_id}_labels_train"


train_tiles = [clean_string(s) for s in next(os.walk(tr_img_path))[1]]
tr_tiles_id = list(np.unique([int(tr_id.split("_")[0]) for tr_id in train_tiles]))
tr_tiles_id = [f"{number:02d}" for number in tr_tiles_id]

# %%
from torch.utils.data import DataLoader
from torch.utils.data import Dataset as BaseDataset

# %%
class Dataset(BaseDataset):
    """FieldBoundary Dataset. Read images, apply augmentation and preprocessing transformations.

    Args:
        images_dir (str): path to images folder
        masks_dir (str): path to segmentation masks folder
        class_values (list): values of classes to extract from segmentation mask
        augmentation (albumentations.Compose): data transfromation pipeline
            (e.g. flip, scale, etc.)
        preprocessing (albumentations.Compose): data preprocessing
            (e.g. noralization, shape manipulation, etc.)

    """
    def __init__(self, tiles_ids, imgs_dir, masks_dir,
                 data_type='train', augmentation=None,
                 bands=[1,2,3,4],
                ):
        self.ids = tiles_ids
        self.imgs_dir = imgs_dir
        self.masks_dir = masks_dir
        self.data_type = data_type
        self.augmentation = augmentation
        self.bands = bands

    def __len__(self):
        return len(self.ids)



    def normalize(self, array: np.ndarray):
        array_min, array_max = array.min(), array.max()
        return (array - array_min) / (array_max - array_min)

    def read_image(self,tile):
        bands = []
        for month in ['03', '04', '08', '10', '11', '12']:
            m_bands=[]
            for b in self.bands:
                band_pth = f'{self.imgs_dir}/{dataset_id}_source_{self.data_type}_{tile}_2021_{month}/B0{b}.tif'
                band = rio.open(band_pth)
                band_array = band.read(1).astype(float)
                band_array = band_array.astype(np.float32)
                band_array = self.normalize(band_array)
                m_bands.append(band_array)
            m_bands = np.stack(m_bands, axis=-1)
            bands.append(m_bands)
        x_arr= np.dstack(bands)
        del bands
        return x_arr

    def read_mask(self,tile):

        mask_pth = f'{self.masks_dir}/{dataset_id}_labels_train_{tile}/raster_labels.tif'
        boundary_mask = rio.open(mask_pth)
        boundary_mask = boundary_mask.read(1).astype('float')
        return boundary_mask


    def __getitem__(self, i):

        # read data
        tile = self.ids[i]
        x_arr = self.read_image(tile)

        if self.masks_dir is not None:
            mask = self.read_mask(tile)
            # apply augmentations
            if self.augmentation:
                sample = self.augmentation(image=x_arr,mask=mask)
                x_arr, mask = sample['image'], sample['mask']

        else:
            mask = np.zeros((256,256))

        x_arr = np.transpose(x_arr, [2, 0, 1])
        return x_arr, mask

# %%
import albumentations as A
def get_training_augmentation():
    train_transform = [
        A.HorizontalFlip(p=0.5),
        A.VerticalFlip(p=0.5),
        A.RandomRotate90(p=0.50),

    ]
    return A.Compose(train_transform)

# %% [markdown]
# ### Segmentation model training

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
ENCODER = 'efficientnet-b3'
ENCODER_WEIGHTS = 'imagenet'
ACTIVATION = 'sigmoid' # could be None for logits or 'softmax2d' for multiclass segmentation
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# %%
# get learning rate
def get_lr(opt):
    for param_group in opt.param_groups:
        return param_group['lr']

BATCH_SIZE = 8
LR = 0.01
epochs = 150

# %%
########################## Binary #########################################
set_seed(2022)
gkf = GroupKFold(n_splits=10)
F1_scores = []
idx=1
for tr_idx, val_idx in gkf.split(tr_tiles_id, tr_tiles_id, tr_tiles_id):
    print(f'*************** Fold {idx} *******************')
    tr_ids = list(np.array(tr_tiles_id)[tr_idx])
    val_ids = list(np.array(tr_tiles_id)[val_idx])

    tr_dataset = Dataset(tr_ids, tr_img_path, tr_lbl_path,
                         augmentation=get_training_augmentation(),
                        )

    val_dataset = Dataset(val_ids, tr_img_path, tr_lbl_path,
                          augmentation=None,
                         )

    tr_dataloader = DataLoader(tr_dataset, batch_size=BATCH_SIZE, shuffle=True)
    val_dataloader = DataLoader(val_dataset, batch_size=1, shuffle=False)

    # create segmentation model with pretrained encoder
    model = smp.Unet(
        encoder_name="efficientnet-b3",
        encoder_weights=ENCODER_WEIGHTS,
        in_channels=48,
        classes=1,
        activation=ACTIVATION,
    )


    # define optomizer
    optim = torch.optim.Adam([
        dict(params=model.parameters(), lr=LR),
    ])
    lr_scheduler = ReduceLROnPlateau(optim, mode='min',
                                     factor=0.5, patience=10)

    # Segmentation models losses can be combined together by '+' and scaled by integer or float factor
    dice_loss = smp.losses.DiceLoss(mode="binary",from_logits=False, smooth=1e-5)
    dice_loss.__name__ = 'Dice_loss'
    metrics = [smp_utils.metrics.Fscore(threshold=0.5)]

    # create epoch runners
    # it is a simple loop of iterating over dataloader`s samples
    train_epoch = smp_utils.train.TrainEpoch(
        model,
        loss=dice_loss,
        metrics=metrics,
        optimizer=optim,
        device=DEVICE,
        verbose=True,
    )

    valid_epoch = smp_utils.train.ValidEpoch(
        model,
        loss=dice_loss,
        metrics=metrics,
        device=DEVICE,
        verbose=True,
    )


    max_score = 0
    max_loss = np.inf
    for i in range(0, epochs):
        current_lr = get_lr(optim)
        print(f'\n ############## Epoch: {i} , lr: {current_lr}')
        train_logs = train_epoch.run(tr_dataloader)
        valid_logs = valid_epoch.run(val_dataloader)


        if valid_logs['Dice_loss'] < max_loss:
            max_loss = valid_logs['Dice_loss']
            best_model_wts = copy.deepcopy(model.state_dict())
            torch.save(model.state_dict(), f'./best_model_{idx}.pth')

            print('Model saved!')

        lr_scheduler.step(valid_logs['Dice_loss'])
        if current_lr != get_lr(optim):
            print("Loading best model weights!")
            model.load_state_dict(best_model_wts)
            # create epoch runners
            # it is a simple loop of iterating over dataloader`s samples
            train_epoch = smp_utils.train.TrainEpoch(model, loss=dice_loss,
                                                     metrics=metrics, optimizer=optim,
                                                     device=DEVICE,verbose=True,)

            valid_epoch = smp_utils.train.ValidEpoch(model, loss=dice_loss,
                                                     metrics=metrics,
                                                     device=DEVICE,
                                                     verbose=True,)


    # Validation
    model.load_state_dict(torch.load(f'./best_model_{idx}.pth'))
    valid_epoch = smp_utils.train.ValidEpoch(model,
                                         loss=dice_loss,
                                         metrics=metrics,
                                         device=DEVICE,verbose=False)
    logs = valid_epoch.run(val_dataloader)

    print('f1-score: ', logs['fscore'])

    F1_scores.append(logs['fscore'])
    idx+=1

print(f'Ensemble F1 score : {np.mean(F1_scores)} ')
# Out:
# *************** Fold 1 *******************
# Downloading: "https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b3-5fb5a3c3.pth" to /root/.cache/torch/hub/checkpoints/efficientnet-b3-5fb5a3c3.pth
#   0%|          | 0.00/47.1M [00:00<?, ?B/s]
#  ############## Epoch: 0 , lr: 0.01
# train: 100%|██████████| 7/7 [00:27<00:00,  3.97s/it, Dice_loss - 0.8799, fscore - 0.7957]
# valid: 100%|██████████| 6/6 [00:01<00:00,  3.19it/s, Dice_loss - 0.8884, fscore - 0.1116]
# Model saved!
#
#  ############## Epoch: 1 , lr: 0.01
# train: 100%|██████████| 7/7 [00:09<00:00,  1.33s/it, Dice_loss - 0.8128, fscore - 0.8955]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.77it/s, Dice_loss - 0.8968, fscore - 0.1032]
#
#  ############## Epoch: 2 , lr: 0.01
# train: 100%|██████████| 7/7 [00:08<00:00,  1.25s/it, Dice_loss - 0.7311, fscore - 0.8885]
# valid: 100%|██████████| 6/6 [00:01<00:00,  5.36it/s, Dice_loss - 0.9972, fscore - 0.002825]
#
#  ############## Epoch: 3 , lr: 0.01
# train: 100%|██████████| 7/7 [00:09<00:00,  1.36s/it, Dice_loss - 0.6673, fscore - 0.9105]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.42it/s, Dice_loss - 0.956, fscore - 0.04397]
#
#  ############## Epoch: 4 , lr: 0.01
# train: 100%|██████████| 7/7 [00:09<00:00,  1.30s/it, Dice_loss - 0.6516, fscore - 0.9099]
# valid: 100%|██████████| 6/6 [00:01<00:00,  5.52it/s, Dice_loss - 0.8948, fscore - 0.1052]
#
#  ############## Epoch: 5 , lr: 0.01
# train: 100%|██████████| 7/7 [00:09<00:00,  1.33s/it, Dice_loss - 0.6551, fscore - 0.828]
# valid: 100%|██████████| 6/6 [00:01<00:00,  5.14it/s, Dice_loss - 0.893, fscore - 0.107]
#
#  ############## Epoch: 6 , lr: 0.01
# train: 100%|██████████| 7/7 [00:09<00:00,  1.37s/it, Dice_loss - 0.6344, fscore - 0.9091]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.51it/s, Dice_loss - 0.9338, fscore - 0.06617]
#
#  ############## Epoch: 7 , lr: 0.01
# train: 100%|██████████| 7/7 [00:08<00:00,  1.26s/it, Dice_loss - 0.6496, fscore - 0.8652]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.82it/s, Dice_loss - 0.8944, fscore - 0.1056]
#
#  ############## Epoch: 8 , lr: 0.01
# train: 100%|██████████| 7/7 [00:08<00:00,  1.28s/it, Dice_loss - 0.6244, fscore - 0.9224]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.33it/s, Dice_loss - 0.8926, fscore - 0.1074]
#
#  ############## Epoch: 9 , lr: 0.01
# train: 100%|██████████| 7/7 [00:09<00:00,  1.36s/it, Dice_loss - 0.6157, fscore - 0.9145]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.74it/s, Dice_loss - 0.8942, fscore - 0.1058]
#
#  ############## Epoch: 10 , lr: 0.01
# train: 100%|██████████| 7/7 [00:09<00:00,  1.41s/it, Dice_loss - 0.6189, fscore - 0.926]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.20it/s, Dice_loss - 0.8942, fscore - 0.1058]
#
#  ############## Epoch: 11 , lr: 0.01
# train: 100%|██████████| 7/7 [00:09<00:00,  1.38s/it, Dice_loss - 0.6072, fscore - 0.9355]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.57it/s, Dice_loss - 0.8898, fscore - 0.1102]
# Loading best model weights!
#
#  ############## Epoch: 12 , lr: 0.005
# train: 100%|██████████| 7/7 [00:10<00:00,  1.45s/it, Dice_loss - 0.8289, fscore - 0.8681]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.44it/s, Dice_loss - 0.8968, fscore - 0.1032]
#
#  ############## Epoch: 13 , lr: 0.005
# train: 100%|██████████| 7/7 [00:09<00:00,  1.36s/it, Dice_loss - 0.7814, fscore - 0.9489]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.62it/s, Dice_loss - 1.0, fscore - 3.008e-11]
#
#  ############## Epoch: 14 , lr: 0.005
# train: 100%|██████████| 7/7 [00:09<00:00,  1.29s/it, Dice_loss - 0.7259, fscore - 0.9164]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.76it/s, Dice_loss - 0.8849, fscore - 0.1151]
# Model saved!
#
#  ############## Epoch: 15 , lr: 0.005
# train: 100%|██████████| 7/7 [00:10<00:00,  1.43s/it, Dice_loss - 0.6782, fscore - 0.9124]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.30it/s, Dice_loss - 0.9749, fscore - 0.02509]
#
#  ############## Epoch: 16 , lr: 0.005
# train: 100%|██████████| 7/7 [00:09<00:00,  1.37s/it, Dice_loss - 0.6496, fscore - 0.9492]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.45it/s, Dice_loss - 0.9194, fscore - 0.08057]
#
#  ############## Epoch: 17 , lr: 0.005
# train: 100%|██████████| 7/7 [00:09<00:00,  1.39s/it, Dice_loss - 0.6226, fscore - 0.9082]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.72it/s, Dice_loss - 0.889, fscore - 0.111]
#
#  ############## Epoch: 18 , lr: 0.005
# train: 100%|██████████| 7/7 [00:09<00:00,  1.34s/it, Dice_loss - 0.6358, fscore - 0.8981]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.13it/s, Dice_loss - 0.8897, fscore - 0.1103]
#
#  ############## Epoch: 19 , lr: 0.005
# train: 100%|██████████| 7/7 [00:09<00:00,  1.32s/it, Dice_loss - 0.6272, fscore - 0.8998]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.56it/s, Dice_loss - 0.8904, fscore - 0.1096]
#
#  ############## Epoch: 20 , lr: 0.005
# train: 100%|██████████| 7/7 [00:09<00:00,  1.30s/it, Dice_loss - 0.6074, fscore - 0.9252]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.61it/s, Dice_loss - 0.8939, fscore - 0.1061]
#
#  ############## Epoch: 21 , lr: 0.005
# train: 100%|██████████| 7/7 [00:09<00:00,  1.30s/it, Dice_loss - 0.6169, fscore - 0.8913]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.36it/s, Dice_loss - 0.9186, fscore - 0.08146]
#
#  ############## Epoch: 22 , lr: 0.005
# train: 100%|██████████| 7/7 [00:09<00:00,  1.31s/it, Dice_loss - 0.6092, fscore - 0.9083]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.10it/s, Dice_loss - 0.9971, fscore - 0.002913]
#
#  ############## Epoch: 23 , lr: 0.005
# train: 100%|██████████| 7/7 [00:09<00:00,  1.30s/it, Dice_loss - 0.5946, fscore - 0.948]
# valid: 100%|██████████| 6/6 [00:01<00:00,  5.60it/s, Dice_loss - 0.9999, fscore - 4.895e-11]
#
#  ############## Epoch: 24 , lr: 0.005
# train: 100%|██████████| 7/7 [00:09<00:00,  1.38s/it, Dice_loss - 0.6019, fscore - 0.9152]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.21it/s, Dice_loss - 0.9998, fscore - 4.905e-11]
#
#  ############## Epoch: 25 , lr: 0.005
# train: 100%|██████████| 7/7 [00:08<00:00,  1.25s/it, Dice_loss - 0.6037, fscore - 0.9165]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.58it/s, Dice_loss - 0.9992, fscore - 0.0003611]
# Loading best model weights!
#
#  ############## Epoch: 26 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:09<00:00,  1.29s/it, Dice_loss - 0.6772, fscore - 0.9099]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.76it/s, Dice_loss - 0.9969, fscore - 0.003141]
#
#  ############## Epoch: 27 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:09<00:00,  1.37s/it, Dice_loss - 0.6758, fscore - 0.9215]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.59it/s, Dice_loss - 0.8839, fscore - 0.1161]
# Model saved!
#
#  ############## Epoch: 28 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:08<00:00,  1.25s/it, Dice_loss - 0.6663, fscore - 0.8704]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.09it/s, Dice_loss - 0.9382, fscore - 0.06188]
#
#  ############## Epoch: 29 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:09<00:00,  1.30s/it, Dice_loss - 0.6392, fscore - 0.9158]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.56it/s, Dice_loss - 0.9271, fscore - 0.07262]
#
#  ############## Epoch: 30 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:10<00:00,  1.46s/it, Dice_loss - 0.6116, fscore - 0.933]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.78it/s, Dice_loss - 0.958, fscore - 0.03926]
#
#  ############## Epoch: 31 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:08<00:00,  1.24s/it, Dice_loss - 0.6234, fscore - 0.9292]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.66it/s, Dice_loss - 0.9872, fscore - 0.009629]
#
#  ############## Epoch: 32 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:08<00:00,  1.24s/it, Dice_loss - 0.6148, fscore - 0.9232]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.74it/s, Dice_loss - 0.8525, fscore - 0.1489]
# Model saved!
#
#  ############## Epoch: 33 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:09<00:00,  1.32s/it, Dice_loss - 0.6078, fscore - 0.9145]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.74it/s, Dice_loss - 0.9853, fscore - 0.01328]
#
#  ############## Epoch: 34 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:08<00:00,  1.26s/it, Dice_loss - 0.6054, fscore - 0.921]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.46it/s, Dice_loss - 0.824, fscore - 0.1778]
# Model saved!
#
#  ############## Epoch: 35 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:08<00:00,  1.25s/it, Dice_loss - 0.5992, fscore - 0.9301]
# valid: 100%|██████████| 6/6 [00:01<00:00,  5.30it/s, Dice_loss - 0.7704, fscore - 0.2306]
# Model saved!
#
#  ############## Epoch: 36 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:09<00:00,  1.38s/it, Dice_loss - 0.5985, fscore - 0.9043]
# valid: 100%|██████████| 6/6 [00:01<00:00,  5.53it/s, Dice_loss - 0.8201, fscore - 0.1796]
#
#  ############## Epoch: 37 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:08<00:00,  1.24s/it, Dice_loss - 0.5942, fscore - 0.8942]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.24it/s, Dice_loss - 0.8033, fscore - 0.1974]
#
#  ############## Epoch: 38 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:09<00:00,  1.37s/it, Dice_loss - 0.5858, fscore - 0.9342]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.40it/s, Dice_loss - 0.7854, fscore - 0.2162]
#
#  ############## Epoch: 39 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:09<00:00,  1.36s/it, Dice_loss - 0.5828, fscore - 0.9315]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.63it/s, Dice_loss - 0.7758, fscore - 0.2245]
#
#  ############## Epoch: 40 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:09<00:00,  1.34s/it, Dice_loss - 0.592, fscore - 0.9471]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.63it/s, Dice_loss - 0.804, fscore - 0.196]
#
#  ############## Epoch: 41 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:09<00:00,  1.32s/it, Dice_loss - 0.5797, fscore - 0.9079]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.58it/s, Dice_loss - 0.7552, fscore - 0.2469]
# Model saved!
#
#  ############## Epoch: 42 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:09<00:00,  1.41s/it, Dice_loss - 0.5777, fscore - 0.9056]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.49it/s, Dice_loss - 0.7418, fscore - 0.2596]
# Model saved!
#
#  ############## Epoch: 43 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:08<00:00,  1.27s/it, Dice_loss - 0.5769, fscore - 0.9156]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.50it/s, Dice_loss - 0.8164, fscore - 0.1841]
#
#  ############## Epoch: 44 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:08<00:00,  1.28s/it, Dice_loss - 0.5712, fscore - 0.9446]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.46it/s, Dice_loss - 0.7646, fscore - 0.2356]
#
#  ############## Epoch: 45 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:09<00:00,  1.37s/it, Dice_loss - 0.5682, fscore - 0.9473]
# valid: 100%|██████████| 6/6 [00:01<00:00,  6.00it/s, Dice_loss - 0.8179, fscore - 0.1827]
#
#  ############## Epoch: 46 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:09<00:00,  1.35s/it, Dice_loss - 0.5594, fscore - 0.9486]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.51it/s, Dice_loss - 0.8211, fscore - 0.1803]
#
#  ############## Epoch: 47 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:09<00:00,  1.37s/it, Dice_loss - 0.5552, fscore - 0.939]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.73it/s, Dice_loss - 0.8077, fscore - 0.1923]
#
#  ############## Epoch: 48 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:09<00:00,  1.35s/it, Dice_loss - 0.5674, fscore - 0.9657]
# valid: 100%|██████████| 6/6 [00:01<00:00,  5.56it/s, Dice_loss - 0.7589, fscore - 0.2418]
#
#  ############## Epoch: 49 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:09<00:00,  1.37s/it, Dice_loss - 0.5658, fscore - 0.9547]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.06it/s, Dice_loss - 0.7526, fscore - 0.2482]
#
#  ############## Epoch: 50 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:08<00:00,  1.26s/it, Dice_loss - 0.5715, fscore - 0.8917]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.35it/s, Dice_loss - 0.7724, fscore - 0.228]
#
#  ############## Epoch: 51 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:10<00:00,  1.50s/it, Dice_loss - 0.5471, fscore - 0.9865]
# valid: 100%|██████████| 6/6 [00:01<00:00,  5.99it/s, Dice_loss - 0.7606, fscore - 0.2392]
#
#  ############## Epoch: 52 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:10<00:00,  1.52s/it, Dice_loss - 0.5483, fscore - 0.9881]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.39it/s, Dice_loss - 0.7393, fscore - 0.2618]
# Model saved!
#
#  ############## Epoch: 53 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:10<00:00,  1.54s/it, Dice_loss - 0.5469, fscore - 0.959]
# valid: 100%|██████████| 6/6 [00:01<00:00,  5.98it/s, Dice_loss - 0.7642, fscore - 0.2359]
#
#  ############## Epoch: 54 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:10<00:00,  1.47s/it, Dice_loss - 0.542, fscore - 0.9686]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.64it/s, Dice_loss - 0.7442, fscore - 0.257]
#
#  ############## Epoch: 55 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:08<00:00,  1.24s/it, Dice_loss - 0.5677, fscore - 0.93]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.70it/s, Dice_loss - 0.7362, fscore - 0.2643]
# Model saved!
#
#  ############## Epoch: 56 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:09<00:00,  1.36s/it, Dice_loss - 0.5609, fscore - 0.9525]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.61it/s, Dice_loss - 0.7314, fscore - 0.2691]
# Model saved!
#
#  ############## Epoch: 57 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:10<00:00,  1.43s/it, Dice_loss - 0.5544, fscore - 0.9488]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.24it/s, Dice_loss - 0.7266, fscore - 0.274]
# Model saved!
#
#  ############## Epoch: 58 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:09<00:00,  1.40s/it, Dice_loss - 0.5502, fscore - 0.9354]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.43it/s, Dice_loss - 0.6916, fscore - 0.3093]
# Model saved!
#
#  ############## Epoch: 59 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:09<00:00,  1.39s/it, Dice_loss - 0.5412, fscore - 0.9415]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.06it/s, Dice_loss - 0.7111, fscore - 0.2888]
#
#  ############## Epoch: 60 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:10<00:00,  1.47s/it, Dice_loss - 0.5388, fscore - 0.989]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.24it/s, Dice_loss - 0.7367, fscore - 0.2639]
#
#  ############## Epoch: 61 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:09<00:00,  1.36s/it, Dice_loss - 0.5344, fscore - 0.9604]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.32it/s, Dice_loss - 0.7413, fscore - 0.2588]
#
#  ############## Epoch: 62 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:08<00:00,  1.28s/it, Dice_loss - 0.5509, fscore - 0.9224]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.71it/s, Dice_loss - 0.7316, fscore - 0.2689]
#
#  ############## Epoch: 63 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:09<00:00,  1.34s/it, Dice_loss - 0.553, fscore - 0.9318]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.26it/s, Dice_loss - 0.7357, fscore - 0.2645]
#
#  ############## Epoch: 64 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:09<00:00,  1.32s/it, Dice_loss - 0.5323, fscore - 0.969]
# valid: 100%|██████████| 6/6 [00:01<00:00,  5.12it/s, Dice_loss - 0.7032, fscore - 0.2976]
#
#  ############## Epoch: 65 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:09<00:00,  1.30s/it, Dice_loss - 0.5337, fscore - 0.9466]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.63it/s, Dice_loss - 0.7624, fscore - 0.2375]
#
#  ############## Epoch: 66 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:09<00:00,  1.35s/it, Dice_loss - 0.5443, fscore - 0.9438]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.92it/s, Dice_loss - 0.7306, fscore - 0.2694]
#
#  ############## Epoch: 67 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:08<00:00,  1.26s/it, Dice_loss - 0.5477, fscore - 0.961]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.63it/s, Dice_loss - 0.7309, fscore - 0.2692]
#
#  ############## Epoch: 68 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:08<00:00,  1.28s/it, Dice_loss - 0.5366, fscore - 0.9569]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.78it/s, Dice_loss - 0.7147, fscore - 0.2862]
#
#  ############## Epoch: 69 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:09<00:00,  1.30s/it, Dice_loss - 0.5329, fscore - 0.9554]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.70it/s, Dice_loss - 0.7244, fscore - 0.2764]
# Loading best model weights!
#
#  ############## Epoch: 70 , lr: 0.00125
# train: 100%|██████████| 7/7 [00:09<00:00,  1.33s/it, Dice_loss - 0.5393, fscore - 0.9567]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.58it/s, Dice_loss - 0.6937, fscore - 0.3069]
#
#  ############## Epoch: 71 , lr: 0.00125
# train: 100%|██████████| 7/7 [00:08<00:00,  1.22s/it, Dice_loss - 0.5519, fscore - 0.9221]
# valid: 100%|██████████| 6/6 [00:00<00:00,  7.02it/s, Dice_loss - 0.7014, fscore - 0.2988]
#
#  ############## Epoch: 72 , lr: 0.00125
# train: 100%|██████████| 7/7 [00:09<00:00,  1.36s/it, Dice_loss - 0.5216, fscore - 1.0]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.57it/s, Dice_loss - 0.7152, fscore - 0.2864]
#
#  ############## Epoch: 73 , lr: 0.00125
# train: 100%|██████████| 7/7 [00:08<00:00,  1.28s/it, Dice_loss - 0.5226, fscore - 0.9803]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.49it/s, Dice_loss - 0.721, fscore - 0.2799]
#
#  ############## Epoch: 74 , lr: 0.00125
# train: 100%|██████████| 7/7 [00:09<00:00,  1.30s/it, Dice_loss - 0.5194, fscore - 0.9842]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.97it/s, Dice_loss - 0.7093, fscore - 0.2917]
#
#  ############## Epoch: 75 , lr: 0.00125
# train: 100%|██████████| 7/7 [00:08<00:00,  1.26s/it, Dice_loss - 0.5319, fscore - 0.9734]
# valid: 100%|██████████| 6/6 [00:01<00:00,  4.79it/s, Dice_loss - 0.7183, fscore - 0.2822]
#
#  ############## Epoch: 76 , lr: 0.00125
# train: 100%|██████████| 7/7 [00:08<00:00,  1.24s/it, Dice_loss - 0.5417, fscore - 0.9333]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.61it/s, Dice_loss - 0.7098, fscore - 0.2908]
#
#  ############## Epoch: 77 , lr: 0.00125
# train: 100%|██████████| 7/7 [00:09<00:00,  1.35s/it, Dice_loss - 0.5224, fscore - 0.9622]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.94it/s, Dice_loss - 0.7125, fscore - 0.2877]
#
#  ############## Epoch: 78 , lr: 0.00125
# train: 100%|██████████| 7/7 [00:09<00:00,  1.29s/it, Dice_loss - 0.5558, fscore - 0.9189]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.74it/s, Dice_loss - 0.7157, fscore - 0.2846]
#
#  ############## Epoch: 79 , lr: 0.00125
# train: 100%|██████████| 7/7 [00:10<00:00,  1.52s/it, Dice_loss - 0.5125, fscore - 0.977]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.81it/s, Dice_loss - 0.7422, fscore - 0.258]
#
#  ############## Epoch: 80 , lr: 0.00125
# train: 100%|██████████| 7/7 [00:08<00:00,  1.25s/it, Dice_loss - 0.5316, fscore - 0.9626]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.89it/s, Dice_loss - 0.7429, fscore - 0.2568]
# Loading best model weights!
#
#  ############## Epoch: 81 , lr: 0.000625
# train: 100%|██████████| 7/7 [00:08<00:00,  1.21s/it, Dice_loss - 0.5406, fscore - 0.9506]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.90it/s, Dice_loss - 0.6904, fscore - 0.3108]
# Model saved!
#
#  ############## Epoch: 82 , lr: 0.000625
# train: 100%|██████████| 7/7 [00:09<00:00,  1.35s/it, Dice_loss - 0.5318, fscore - 0.9921]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.87it/s, Dice_loss - 0.6979, fscore - 0.3033]
#
#  ############## Epoch: 83 , lr: 0.000625
# train: 100%|██████████| 7/7 [00:08<00:00,  1.27s/it, Dice_loss - 0.5245, fscore - 0.9802]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.91it/s, Dice_loss - 0.7016, fscore - 0.2994]
#
#  ############## Epoch: 84 , lr: 0.000625
# train: 100%|██████████| 7/7 [00:08<00:00,  1.22s/it, Dice_loss - 0.5288, fscore - 0.954]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.99it/s, Dice_loss - 0.7058, fscore - 0.2954]
#
#  ############## Epoch: 85 , lr: 0.000625
# train: 100%|██████████| 7/7 [00:09<00:00,  1.33s/it, Dice_loss - 0.5271, fscore - 0.9658]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.83it/s, Dice_loss - 0.7112, fscore - 0.2897]
#
#  ############## Epoch: 86 , lr: 0.000625
# train: 100%|██████████| 7/7 [00:08<00:00,  1.29s/it, Dice_loss - 0.5155, fscore - 0.987]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.20it/s, Dice_loss - 0.7138, fscore - 0.2879]
#
#  ############## Epoch: 87 , lr: 0.000625
# train: 100%|██████████| 7/7 [00:08<00:00,  1.24s/it, Dice_loss - 0.5169, fscore - 0.9793]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.46it/s, Dice_loss - 0.7144, fscore - 0.2865]
#
#  ############## Epoch: 88 , lr: 0.000625
# train: 100%|██████████| 7/7 [00:09<00:00,  1.32s/it, Dice_loss - 0.5593, fscore - 0.9459]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.74it/s, Dice_loss - 0.7103, fscore - 0.291]
#
#  ############## Epoch: 89 , lr: 0.000625
# train: 100%|██████████| 7/7 [00:08<00:00,  1.26s/it, Dice_loss - 0.5281, fscore - 0.9415]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.95it/s, Dice_loss - 0.7099, fscore - 0.2913]
#
#  ############## Epoch: 90 , lr: 0.000625
# train: 100%|██████████| 7/7 [00:08<00:00,  1.22s/it, Dice_loss - 0.5347, fscore - 0.9426]
# valid: 100%|██████████| 6/6 [00:00<00:00,  7.07it/s, Dice_loss - 0.7202, fscore - 0.2802]
#
#  ############## Epoch: 91 , lr: 0.000625
# train: 100%|██████████| 7/7 [00:09<00:00,  1.40s/it, Dice_loss - 0.5134, fscore - 0.9796]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.77it/s, Dice_loss - 0.7339, fscore - 0.2664]
#
#  ############## Epoch: 92 , lr: 0.000625
# train: 100%|██████████| 7/7 [00:08<00:00,  1.28s/it, Dice_loss - 0.5349, fscore - 0.9363]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.89it/s, Dice_loss - 0.7344, fscore - 0.2669]
# Loading best model weights!
#
#  ############## Epoch: 93 , lr: 0.0003125
# train: 100%|██████████| 7/7 [00:08<00:00,  1.23s/it, Dice_loss - 0.5757, fscore - 0.9189]
# valid: 100%|██████████| 6/6 [00:00<00:00,  7.07it/s, Dice_loss - 0.6913, fscore - 0.3096]
#
#  ############## Epoch: 94 , lr: 0.0003125
# train: 100%|██████████| 7/7 [00:08<00:00,  1.28s/it, Dice_loss - 0.5464, fscore - 0.954]
# valid: 100%|██████████| 6/6 [00:01<00:00,  5.62it/s, Dice_loss - 0.6926, fscore - 0.3082]
#
#  ############## Epoch: 95 , lr: 0.0003125
# train: 100%|██████████| 7/7 [00:08<00:00,  1.27s/it, Dice_loss - 0.5399, fscore - 0.963]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.95it/s, Dice_loss - 0.6968, fscore - 0.3042]
#
#  ############## Epoch: 96 , lr: 0.0003125
# train: 100%|██████████| 7/7 [00:08<00:00,  1.22s/it, Dice_loss - 0.528, fscore - 0.9583]
# valid: 100%|██████████| 6/6 [00:01<00:00,  5.66it/s, Dice_loss - 0.7026, fscore - 0.2978]
#
#  ############## Epoch: 97 , lr: 0.0003125
# train: 100%|██████████| 7/7 [00:08<00:00,  1.22s/it, Dice_loss - 0.5468, fscore - 0.9501]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.61it/s, Dice_loss - 0.7045, fscore - 0.2953]
#
#  ############## Epoch: 98 , lr: 0.0003125
# train: 100%|██████████| 7/7 [00:09<00:00,  1.34s/it, Dice_loss - 0.527, fscore - 0.9711]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.98it/s, Dice_loss - 0.7043, fscore - 0.297]
#
#  ############## Epoch: 99 , lr: 0.0003125
# train: 100%|██████████| 7/7 [00:09<00:00,  1.29s/it, Dice_loss - 0.5332, fscore - 0.9631]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.74it/s, Dice_loss - 0.7095, fscore - 0.2911]
#
#  ############## Epoch: 100 , lr: 0.0003125
# train: 100%|██████████| 7/7 [00:08<00:00,  1.26s/it, Dice_loss - 0.525, fscore - 0.9714]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.98it/s, Dice_loss - 0.7116, fscore - 0.29]
#
#  ############## Epoch: 101 , lr: 0.0003125
# train: 100%|██████████| 7/7 [00:09<00:00,  1.36s/it, Dice_loss - 0.5214, fscore - 0.983]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.84it/s, Dice_loss - 0.7098, fscore - 0.2916]
#
#  ############## Epoch: 102 , lr: 0.0003125
# train: 100%|██████████| 7/7 [00:08<00:00,  1.22s/it, Dice_loss - 0.5325, fscore - 0.9509]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.83it/s, Dice_loss - 0.7081, fscore - 0.2925]
#
#  ############## Epoch: 103 , lr: 0.0003125
# train: 100%|██████████| 7/7 [00:08<00:00,  1.26s/it, Dice_loss - 0.5357, fscore - 0.9509]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.90it/s, Dice_loss - 0.7092, fscore - 0.2911]
# Loading best model weights!
#
#  ############## Epoch: 104 , lr: 0.00015625
# train: 100%|██████████| 7/7 [00:09<00:00,  1.37s/it, Dice_loss - 0.5353, fscore - 0.9708]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.80it/s, Dice_loss - 0.6909, fscore - 0.3099]
#
#  ############## Epoch: 105 , lr: 0.00015625
# train: 100%|██████████| 7/7 [00:09<00:00,  1.30s/it, Dice_loss - 0.5332, fscore - 0.9787]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.80it/s, Dice_loss - 0.6927, fscore - 0.3078]
#
#  ############## Epoch: 106 , lr: 0.00015625
# train: 100%|██████████| 7/7 [00:08<00:00,  1.28s/it, Dice_loss - 0.5364, fscore - 0.9658]
# valid: 100%|██████████| 6/6 [00:01<00:00,  5.70it/s, Dice_loss - 0.6931, fscore - 0.3081]
#
#  ############## Epoch: 107 , lr: 0.00015625
# train: 100%|██████████| 7/7 [00:09<00:00,  1.38s/it, Dice_loss - 0.5261, fscore - 0.9766]
# valid: 100%|██████████| 6/6 [00:01<00:00,  5.66it/s, Dice_loss - 0.695, fscore - 0.3055]
#
#  ############## Epoch: 108 , lr: 0.00015625
# train: 100%|██████████| 7/7 [00:08<00:00,  1.27s/it, Dice_loss - 0.5292, fscore - 0.965]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.87it/s, Dice_loss - 0.698, fscore - 0.302]
#
#  ############## Epoch: 109 , lr: 0.00015625
# train: 100%|██████████| 7/7 [00:08<00:00,  1.28s/it, Dice_loss - 0.5331, fscore - 0.947]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.80it/s, Dice_loss - 0.7004, fscore - 0.2999]
#
#  ############## Epoch: 110 , lr: 0.00015625
# train: 100%|██████████| 7/7 [00:09<00:00,  1.29s/it, Dice_loss - 0.5245, fscore - 0.9676]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.69it/s, Dice_loss - 0.7031, fscore - 0.2977]
#
#  ############## Epoch: 111 , lr: 0.00015625
# train: 100%|██████████| 7/7 [00:08<00:00,  1.26s/it, Dice_loss - 0.5189, fscore - 0.9754]
# valid: 100%|██████████| 6/6 [00:00<00:00,  7.09it/s, Dice_loss - 0.7025, fscore - 0.2984]
#
#  ############## Epoch: 112 , lr: 0.00015625
# train: 100%|██████████| 7/7 [00:08<00:00,  1.24s/it, Dice_loss - 0.5316, fscore - 0.9611]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.22it/s, Dice_loss - 0.7017, fscore - 0.2992]
#
#  ############## Epoch: 113 , lr: 0.00015625
# train: 100%|██████████| 7/7 [00:09<00:00,  1.31s/it, Dice_loss - 0.5255, fscore - 0.9699]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.58it/s, Dice_loss - 0.702, fscore - 0.2986]
#
#  ############## Epoch: 114 , lr: 0.00015625
# train: 100%|██████████| 7/7 [00:09<00:00,  1.35s/it, Dice_loss - 0.5378, fscore - 0.9436]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.81it/s, Dice_loss - 0.7032, fscore - 0.2971]
# Loading best model weights!
#
#  ############## Epoch: 115 , lr: 7.8125e-05
# train: 100%|██████████| 7/7 [00:08<00:00,  1.29s/it, Dice_loss - 0.5389, fscore - 0.937]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.63it/s, Dice_loss - 0.6895, fscore - 0.3121]
# Model saved!
#
#  ############## Epoch: 116 , lr: 7.8125e-05
# train: 100%|██████████| 7/7 [00:09<00:00,  1.34s/it, Dice_loss - 0.5291, fscore - 0.9623]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.94it/s, Dice_loss - 0.6894, fscore - 0.3116]
# Model saved!
#
#  ############## Epoch: 117 , lr: 7.8125e-05
# train: 100%|██████████| 7/7 [00:09<00:00,  1.30s/it, Dice_loss - 0.5369, fscore - 0.9519]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.98it/s, Dice_loss - 0.6901, fscore - 0.3107]
#
#  ############## Epoch: 118 , lr: 7.8125e-05
# train: 100%|██████████| 7/7 [00:08<00:00,  1.25s/it, Dice_loss - 0.5365, fscore - 0.949]
# valid: 100%|██████████| 6/6 [00:01<00:00,  5.67it/s, Dice_loss - 0.6921, fscore - 0.3086]
#
#  ############## Epoch: 119 , lr: 7.8125e-05
# train: 100%|██████████| 7/7 [00:08<00:00,  1.18s/it, Dice_loss - 0.5245, fscore - 0.949]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.86it/s, Dice_loss - 0.6953, fscore - 0.3045]
#
#  ############## Epoch: 120 , lr: 7.8125e-05
# train: 100%|██████████| 7/7 [00:09<00:00,  1.34s/it, Dice_loss - 0.5266, fscore - 0.9822]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.59it/s, Dice_loss - 0.6988, fscore - 0.3016]
#
#  ############## Epoch: 121 , lr: 7.8125e-05
# train: 100%|██████████| 7/7 [00:08<00:00,  1.27s/it, Dice_loss - 0.527, fscore - 0.9702]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.39it/s, Dice_loss - 0.7009, fscore - 0.2994]
#
#  ############## Epoch: 122 , lr: 7.8125e-05
# train: 100%|██████████| 7/7 [00:09<00:00,  1.32s/it, Dice_loss - 0.5282, fscore - 0.9821]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.88it/s, Dice_loss - 0.7024, fscore - 0.298]
#
#  ############## Epoch: 123 , lr: 7.8125e-05
# train: 100%|██████████| 7/7 [00:09<00:00,  1.31s/it, Dice_loss - 0.5475, fscore - 0.9502]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.84it/s, Dice_loss - 0.7027, fscore - 0.2983]
#
#  ############## Epoch: 124 , lr: 7.8125e-05
# train: 100%|██████████| 7/7 [00:09<00:00,  1.29s/it, Dice_loss - 0.5285, fscore - 0.9628]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.53it/s, Dice_loss - 0.7025, fscore - 0.2984]
#
#  ############## Epoch: 125 , lr: 7.8125e-05
# train: 100%|██████████| 7/7 [00:09<00:00,  1.34s/it, Dice_loss - 0.5232, fscore - 0.9868]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.91it/s, Dice_loss - 0.7027, fscore - 0.299]
#
#  ############## Epoch: 126 , lr: 7.8125e-05
# train: 100%|██████████| 7/7 [00:09<00:00,  1.33s/it, Dice_loss - 0.5297, fscore - 0.956]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.99it/s, Dice_loss - 0.7037, fscore - 0.297]
#
#  ############## Epoch: 127 , lr: 7.8125e-05
# train: 100%|██████████| 7/7 [00:09<00:00,  1.30s/it, Dice_loss - 0.5504, fscore - 0.9445]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.33it/s, Dice_loss - 0.7035, fscore - 0.2973]
# Loading best model weights!
#
#  ############## Epoch: 128 , lr: 3.90625e-05
# train: 100%|██████████| 7/7 [00:08<00:00,  1.27s/it, Dice_loss - 0.5277, fscore - 0.9697]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.82it/s, Dice_loss - 0.6887, fscore - 0.3124]
# Model saved!
#
#  ############## Epoch: 129 , lr: 3.90625e-05
# train: 100%|██████████| 7/7 [00:09<00:00,  1.36s/it, Dice_loss - 0.5359, fscore - 0.9799]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.27it/s, Dice_loss - 0.6888, fscore - 0.3128]
#
#  ############## Epoch: 130 , lr: 3.90625e-05
# train: 100%|██████████| 7/7 [00:08<00:00,  1.21s/it, Dice_loss - 0.5514, fscore - 0.9232]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.85it/s, Dice_loss - 0.6899, fscore - 0.3115]
#
#  ############## Epoch: 131 , lr: 3.90625e-05
# train: 100%|██████████| 7/7 [00:09<00:00,  1.33s/it, Dice_loss - 0.5323, fscore - 0.9661]
# valid: 100%|██████████| 6/6 [00:00<00:00,  7.07it/s, Dice_loss - 0.6922, fscore - 0.3081]
#
#  ############## Epoch: 132 , lr: 3.90625e-05
# train: 100%|██████████| 7/7 [00:09<00:00,  1.40s/it, Dice_loss - 0.5465, fscore - 0.9852]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.92it/s, Dice_loss - 0.694, fscore - 0.3067]
#
#  ############## Epoch: 133 , lr: 3.90625e-05
# train: 100%|██████████| 7/7 [00:08<00:00,  1.27s/it, Dice_loss - 0.5323, fscore - 0.9447]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.53it/s, Dice_loss - 0.6962, fscore - 0.3038]
#
#  ############## Epoch: 134 , lr: 3.90625e-05
# train: 100%|██████████| 7/7 [00:08<00:00,  1.25s/it, Dice_loss - 0.5406, fscore - 0.9391]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.81it/s, Dice_loss - 0.6961, fscore - 0.304]
#
#  ############## Epoch: 135 , lr: 3.90625e-05
# train: 100%|██████████| 7/7 [00:08<00:00,  1.22s/it, Dice_loss - 0.5463, fscore - 0.9299]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.70it/s, Dice_loss - 0.6961, fscore - 0.3035]
#
#  ############## Epoch: 136 , lr: 3.90625e-05
# train: 100%|██████████| 7/7 [00:09<00:00,  1.32s/it, Dice_loss - 0.5624, fscore - 0.919]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.14it/s, Dice_loss - 0.6963, fscore - 0.3037]
#
#  ############## Epoch: 137 , lr: 3.90625e-05
# train: 100%|██████████| 7/7 [00:09<00:00,  1.31s/it, Dice_loss - 0.527, fscore - 0.966]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.75it/s, Dice_loss - 0.6968, fscore - 0.3035]
#
#  ############## Epoch: 138 , lr: 3.90625e-05
# train: 100%|██████████| 7/7 [00:09<00:00,  1.34s/it, Dice_loss - 0.5365, fscore - 0.964]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.54it/s, Dice_loss - 0.6972, fscore - 0.3034]
#
#  ############## Epoch: 139 , lr: 3.90625e-05
# train: 100%|██████████| 7/7 [00:09<00:00,  1.39s/it, Dice_loss - 0.5261, fscore - 0.9709]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.60it/s, Dice_loss - 0.6979, fscore - 0.3032]
# Loading best model weights!
#
#  ############## Epoch: 140 , lr: 1.953125e-05
# train: 100%|██████████| 7/7 [00:08<00:00,  1.26s/it, Dice_loss - 0.529, fscore - 0.9707]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.75it/s, Dice_loss - 0.6888, fscore - 0.3129]
#
#  ############## Epoch: 141 , lr: 1.953125e-05
# train: 100%|██████████| 7/7 [00:08<00:00,  1.28s/it, Dice_loss - 0.5179, fscore - 0.9827]
# valid: 100%|██████████| 6/6 [00:01<00:00,  5.75it/s, Dice_loss - 0.6903, fscore - 0.3107]
#
#  ############## Epoch: 142 , lr: 1.953125e-05
# train: 100%|██████████| 7/7 [00:09<00:00,  1.35s/it, Dice_loss - 0.5506, fscore - 0.9989]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.85it/s, Dice_loss - 0.691, fscore - 0.3093]
#
#  ############## Epoch: 143 , lr: 1.953125e-05
# train: 100%|██████████| 7/7 [00:09<00:00,  1.31s/it, Dice_loss - 0.5232, fscore - 0.997]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.84it/s, Dice_loss - 0.6919, fscore - 0.3091]
#
#  ############## Epoch: 144 , lr: 1.953125e-05
# train: 100%|██████████| 7/7 [00:08<00:00,  1.28s/it, Dice_loss - 0.5418, fscore - 0.9506]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.72it/s, Dice_loss - 0.6919, fscore - 0.3083]
#
#  ############## Epoch: 145 , lr: 1.953125e-05
# train: 100%|██████████| 7/7 [00:09<00:00,  1.35s/it, Dice_loss - 0.5203, fscore - 0.9865]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.55it/s, Dice_loss - 0.6933, fscore - 0.3069]
#
#  ############## Epoch: 146 , lr: 1.953125e-05
# train: 100%|██████████| 7/7 [00:08<00:00,  1.28s/it, Dice_loss - 0.5313, fscore - 0.9597]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.75it/s, Dice_loss - 0.6939, fscore - 0.3058]
#
#  ############## Epoch: 147 , lr: 1.953125e-05
# train: 100%|██████████| 7/7 [00:09<00:00,  1.38s/it, Dice_loss - 0.5287, fscore - 0.9857]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.75it/s, Dice_loss - 0.6946, fscore - 0.306]
#
#  ############## Epoch: 148 , lr: 1.953125e-05
# train: 100%|██████████| 7/7 [00:09<00:00,  1.39s/it, Dice_loss - 0.5431, fscore - 0.9498]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.73it/s, Dice_loss - 0.6949, fscore - 0.3056]
#
#  ############## Epoch: 149 , lr: 1.953125e-05
# train: 100%|██████████| 7/7 [00:08<00:00,  1.25s/it, Dice_loss - 0.5351, fscore - 0.9613]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.97it/s, Dice_loss - 0.6955, fscore - 0.3052]
# f1-score:  0.3124034798320756
# *************** Fold 2 *******************
#
#  ############## Epoch: 0 , lr: 0.01
# train: 100%|██████████| 7/7 [00:09<00:00,  1.39s/it, Dice_loss - 0.8779, fscore - 0.8119]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.73it/s, Dice_loss - 0.9053, fscore - 0.09474]
# Model saved!
#
#  ############## Epoch: 1 , lr: 0.01
# train: 100%|██████████| 7/7 [00:08<00:00,  1.26s/it, Dice_loss - 0.8517, fscore - 0.8381]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.78it/s, Dice_loss - 0.9049, fscore - 0.09511]
# Model saved!
#
#  ############## Epoch: 2 , lr: 0.01
# train: 100%|██████████| 7/7 [00:09<00:00,  1.32s/it, Dice_loss - 0.7927, fscore - 0.9554]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.90it/s, Dice_loss - 0.9042, fscore - 0.09583]
# Model saved!
#
#  ############## Epoch: 3 , lr: 0.01
# train: 100%|██████████| 7/7 [00:08<00:00,  1.28s/it, Dice_loss - 0.7294, fscore - 0.8886]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.77it/s, Dice_loss - 0.9053, fscore - 0.09471]
#
#  ############## Epoch: 4 , lr: 0.01
# train: 100%|██████████| 7/7 [00:09<00:00,  1.33s/it, Dice_loss - 0.6804, fscore - 0.9038]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.73it/s, Dice_loss - 0.9038, fscore - 0.09618]
# Model saved!
#
#  ############## Epoch: 5 , lr: 0.01
# train: 100%|██████████| 7/7 [00:08<00:00,  1.27s/it, Dice_loss - 0.663, fscore - 0.8684]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.65it/s, Dice_loss - 0.9036, fscore - 0.09642]
# Model saved!
#
#  ############## Epoch: 6 , lr: 0.01
# train: 100%|██████████| 7/7 [00:08<00:00,  1.24s/it, Dice_loss - 0.6669, fscore - 0.8378]
# valid: 100%|██████████| 6/6 [00:01<00:00,  5.60it/s, Dice_loss - 0.9014, fscore - 0.09859]
# Model saved!
#
#  ############## Epoch: 7 , lr: 0.01
# train: 100%|██████████| 7/7 [00:09<00:00,  1.34s/it, Dice_loss - 0.6477, fscore - 0.9425]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.00it/s, Dice_loss - 0.9024, fscore - 0.0976]
#
#  ############## Epoch: 8 , lr: 0.01
# train: 100%|██████████| 7/7 [00:08<00:00,  1.27s/it, Dice_loss - 0.6416, fscore - 0.8939]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.53it/s, Dice_loss - 0.9002, fscore - 0.09978]
# Model saved!
#
#  ############## Epoch: 9 , lr: 0.01
# train: 100%|██████████| 7/7 [00:09<00:00,  1.29s/it, Dice_loss - 0.6361, fscore - 0.9049]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.78it/s, Dice_loss - 0.9041, fscore - 0.09589]
#
#  ############## Epoch: 10 , lr: 0.01
# train: 100%|██████████| 7/7 [00:09<00:00,  1.35s/it, Dice_loss - 0.6308, fscore - 0.9285]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.85it/s, Dice_loss - 0.9038, fscore - 0.09622]
#
#  ############## Epoch: 11 , lr: 0.01
# train: 100%|██████████| 7/7 [00:09<00:00,  1.31s/it, Dice_loss - 0.6211, fscore - 0.9097]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.66it/s, Dice_loss - 0.9043, fscore - 0.09566]
#
#  ############## Epoch: 12 , lr: 0.01
# train: 100%|██████████| 7/7 [00:09<00:00,  1.30s/it, Dice_loss - 0.6188, fscore - 0.9072]
# valid: 100%|██████████| 6/6 [00:01<00:00,  5.85it/s, Dice_loss - 0.9057, fscore - 0.09429]
#
#  ############## Epoch: 13 , lr: 0.01
# train: 100%|██████████| 7/7 [00:10<00:00,  1.45s/it, Dice_loss - 0.6085, fscore - 0.9551]
# valid: 100%|██████████| 6/6 [00:01<00:00,  5.97it/s, Dice_loss - 0.9045, fscore - 0.09546]
#
#  ############## Epoch: 14 , lr: 0.01
# train: 100%|██████████| 7/7 [00:09<00:00,  1.37s/it, Dice_loss - 0.6241, fscore - 0.9402]
# valid: 100%|██████████| 6/6 [00:01<00:00,  5.91it/s, Dice_loss - 0.9, fscore - 0.1]
# Model saved!
#
#  ############## Epoch: 15 , lr: 0.01
# train: 100%|██████████| 7/7 [00:08<00:00,  1.28s/it, Dice_loss - 0.6282, fscore - 0.8819]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.64it/s, Dice_loss - 0.9024, fscore - 0.09747]
#
#  ############## Epoch: 16 , lr: 0.01
# train: 100%|██████████| 7/7 [00:08<00:00,  1.28s/it, Dice_loss - 0.6107, fscore - 0.8881]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.83it/s, Dice_loss - 0.9037, fscore - 0.09638]
#
#  ############## Epoch: 17 , lr: 0.01
# train: 100%|██████████| 7/7 [00:09<00:00,  1.35s/it, Dice_loss - 0.596, fscore - 0.9697]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.78it/s, Dice_loss - 0.898, fscore - 0.102]
# Model saved!
#
#  ############## Epoch: 18 , lr: 0.01
# train: 100%|██████████| 7/7 [00:09<00:00,  1.36s/it, Dice_loss - 0.5974, fscore - 0.9144]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.81it/s, Dice_loss - 0.8995, fscore - 0.1005]
#
#  ############## Epoch: 19 , lr: 0.01
# train: 100%|██████████| 7/7 [00:09<00:00,  1.36s/it, Dice_loss - 0.5951, fscore - 0.9407]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.85it/s, Dice_loss - 0.898, fscore - 0.102]
#
#  ############## Epoch: 20 , lr: 0.01
# train: 100%|██████████| 7/7 [00:08<00:00,  1.21s/it, Dice_loss - 0.6154, fscore - 0.9024]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.84it/s, Dice_loss - 0.9445, fscore - 0.05519]
#
#  ############## Epoch: 21 , lr: 0.01
# train: 100%|██████████| 7/7 [00:08<00:00,  1.22s/it, Dice_loss - 0.6023, fscore - 0.8941]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.12it/s, Dice_loss - 0.9757, fscore - 0.02365]
#
#  ############## Epoch: 22 , lr: 0.01
# train: 100%|██████████| 7/7 [00:08<00:00,  1.22s/it, Dice_loss - 0.6006, fscore - 0.9019]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.98it/s, Dice_loss - 0.8967, fscore - 0.103]
# Model saved!
#
#  ############## Epoch: 23 , lr: 0.01
# train: 100%|██████████| 7/7 [00:09<00:00,  1.36s/it, Dice_loss - 0.6067, fscore - 0.9339]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.71it/s, Dice_loss - 0.9701, fscore - 0.02953]
#
#  ############## Epoch: 24 , lr: 0.01
# train: 100%|██████████| 7/7 [00:09<00:00,  1.30s/it, Dice_loss - 0.5885, fscore - 0.9587]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.83it/s, Dice_loss - 0.8986, fscore - 0.1014]
#
#  ############## Epoch: 25 , lr: 0.01
# train: 100%|██████████| 7/7 [00:09<00:00,  1.39s/it, Dice_loss - 0.5883, fscore - 0.9401]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.74it/s, Dice_loss - 0.8942, fscore - 0.1057]
# Model saved!
#
#  ############## Epoch: 26 , lr: 0.01
# train: 100%|██████████| 7/7 [00:09<00:00,  1.30s/it, Dice_loss - 0.5916, fscore - 0.9276]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.83it/s, Dice_loss - 0.8247, fscore - 0.1761]
# Model saved!
#
#  ############## Epoch: 27 , lr: 0.01
# train: 100%|██████████| 7/7 [00:09<00:00,  1.31s/it, Dice_loss - 0.592, fscore - 0.9351]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.58it/s, Dice_loss - 0.7758, fscore - 0.225]
# Model saved!
#
#  ############## Epoch: 28 , lr: 0.01
# train: 100%|██████████| 7/7 [00:08<00:00,  1.24s/it, Dice_loss - 0.5947, fscore - 0.8927]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.70it/s, Dice_loss - 0.8459, fscore - 0.1542]
#
#  ############## Epoch: 29 , lr: 0.01
# train: 100%|██████████| 7/7 [00:10<00:00,  1.44s/it, Dice_loss - 0.5649, fscore - 0.9593]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.98it/s, Dice_loss - 0.8471, fscore - 0.1531]
#
#  ############## Epoch: 30 , lr: 0.01
# train: 100%|██████████| 7/7 [00:09<00:00,  1.33s/it, Dice_loss - 0.5642, fscore - 0.9631]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.60it/s, Dice_loss - 0.864, fscore - 0.1362]
#
#  ############## Epoch: 31 , lr: 0.01
# train: 100%|██████████| 7/7 [00:08<00:00,  1.22s/it, Dice_loss - 0.586, fscore - 0.9239]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.88it/s, Dice_loss - 0.8574, fscore - 0.1427]
#
#  ############## Epoch: 32 , lr: 0.01
# train: 100%|██████████| 7/7 [00:09<00:00,  1.33s/it, Dice_loss - 0.5789, fscore - 0.9055]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.70it/s, Dice_loss - 0.8477, fscore - 0.1521]
#
#  ############## Epoch: 33 , lr: 0.01
# train: 100%|██████████| 7/7 [00:08<00:00,  1.23s/it, Dice_loss - 0.5689, fscore - 0.9395]
# valid: 100%|██████████| 6/6 [00:01<00:00,  5.57it/s, Dice_loss - 0.8679, fscore - 0.1321]
#
#  ############## Epoch: 34 , lr: 0.01
# train: 100%|██████████| 7/7 [00:09<00:00,  1.39s/it, Dice_loss - 0.5673, fscore - 0.9867]
# valid: 100%|██████████| 6/6 [00:01<00:00,  5.20it/s, Dice_loss - 0.8579, fscore - 0.1422]
#
#  ############## Epoch: 35 , lr: 0.01
# train: 100%|██████████| 7/7 [00:09<00:00,  1.39s/it, Dice_loss - 0.5714, fscore - 0.9069]
# valid: 100%|██████████| 6/6 [00:01<00:00,  5.40it/s, Dice_loss - 0.8346, fscore - 0.1653]
#
#  ############## Epoch: 36 , lr: 0.01
# train: 100%|██████████| 7/7 [00:09<00:00,  1.40s/it, Dice_loss - 0.5782, fscore - 0.9291]
# valid: 100%|██████████| 6/6 [00:01<00:00,  5.39it/s, Dice_loss - 0.8955, fscore - 0.1045]
#
#  ############## Epoch: 37 , lr: 0.01
# train: 100%|██████████| 7/7 [00:09<00:00,  1.32s/it, Dice_loss - 0.556, fscore - 0.9561]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.58it/s, Dice_loss - 0.8705, fscore - 0.1294]
#
#  ############## Epoch: 38 , lr: 0.01
# train: 100%|██████████| 7/7 [00:08<00:00,  1.27s/it, Dice_loss - 0.5867, fscore - 0.9099]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.67it/s, Dice_loss - 0.8827, fscore - 0.1174]
# Loading best model weights!
#
#  ############## Epoch: 39 , lr: 0.005
# train: 100%|██████████| 7/7 [00:08<00:00,  1.26s/it, Dice_loss - 0.5771, fscore - 0.9327]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.72it/s, Dice_loss - 0.7706, fscore - 0.23]
# Model saved!
#
#  ############## Epoch: 40 , lr: 0.005
# train: 100%|██████████| 7/7 [00:08<00:00,  1.24s/it, Dice_loss - 0.5746, fscore - 0.9406]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.55it/s, Dice_loss - 0.7884, fscore - 0.2118]
#
#  ############## Epoch: 41 , lr: 0.005
# train: 100%|██████████| 7/7 [00:08<00:00,  1.28s/it, Dice_loss - 0.5815, fscore - 0.9238]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.73it/s, Dice_loss - 0.8022, fscore - 0.198]
#
#  ############## Epoch: 42 , lr: 0.005
# train: 100%|██████████| 7/7 [00:09<00:00,  1.31s/it, Dice_loss - 0.5697, fscore - 0.9369]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.70it/s, Dice_loss - 0.764, fscore - 0.2369]
# Model saved!
#
#  ############## Epoch: 43 , lr: 0.005
# train: 100%|██████████| 7/7 [00:09<00:00,  1.31s/it, Dice_loss - 0.554, fscore - 0.9541]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.45it/s, Dice_loss - 0.7629, fscore - 0.2375]
# Model saved!
#
#  ############## Epoch: 44 , lr: 0.005
# train: 100%|██████████| 7/7 [00:10<00:00,  1.49s/it, Dice_loss - 0.5634, fscore - 0.9612]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.55it/s, Dice_loss - 0.8063, fscore - 0.1941]
#
#  ############## Epoch: 45 , lr: 0.005
# train: 100%|██████████| 7/7 [00:09<00:00,  1.39s/it, Dice_loss - 0.5593, fscore - 0.9639]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.47it/s, Dice_loss - 0.8054, fscore - 0.1946]
#
#  ############## Epoch: 46 , lr: 0.005
# train: 100%|██████████| 7/7 [00:09<00:00,  1.35s/it, Dice_loss - 0.5774, fscore - 0.9259]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.55it/s, Dice_loss - 0.764, fscore - 0.2359]
#
#  ############## Epoch: 47 , lr: 0.005
# train: 100%|██████████| 7/7 [00:09<00:00,  1.34s/it, Dice_loss - 0.5579, fscore - 0.9673]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.86it/s, Dice_loss - 0.8046, fscore - 0.1959]
#
#  ############## Epoch: 48 , lr: 0.005
# train: 100%|██████████| 7/7 [00:09<00:00,  1.40s/it, Dice_loss - 0.562, fscore - 0.9406]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.60it/s, Dice_loss - 0.7625, fscore - 0.2384]
# Model saved!
#
#  ############## Epoch: 49 , lr: 0.005
# train: 100%|██████████| 7/7 [00:08<00:00,  1.25s/it, Dice_loss - 0.5692, fscore - 0.8979]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.79it/s, Dice_loss - 0.7215, fscore - 0.2784]
# Model saved!
#
#  ############## Epoch: 50 , lr: 0.005
# train: 100%|██████████| 7/7 [00:09<00:00,  1.38s/it, Dice_loss - 0.5625, fscore - 0.957]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.75it/s, Dice_loss - 0.7291, fscore - 0.2721]
#
#  ############## Epoch: 51 , lr: 0.005
# train: 100%|██████████| 7/7 [00:08<00:00,  1.19s/it, Dice_loss - 0.569, fscore - 0.9306]
# valid: 100%|██████████| 6/6 [00:01<00:00,  5.84it/s, Dice_loss - 0.7234, fscore - 0.2768]
#
#  ############## Epoch: 52 , lr: 0.005
# train: 100%|██████████| 7/7 [00:08<00:00,  1.26s/it, Dice_loss - 0.5616, fscore - 0.9563]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.91it/s, Dice_loss - 0.7258, fscore - 0.2748]
#
#  ############## Epoch: 53 , lr: 0.005
# train: 100%|██████████| 7/7 [00:08<00:00,  1.26s/it, Dice_loss - 0.5603, fscore - 0.931]
# valid: 100%|██████████| 6/6 [00:01<00:00,  5.60it/s, Dice_loss - 0.7186, fscore - 0.2815]
# Model saved!
#
#  ############## Epoch: 54 , lr: 0.005
# train: 100%|██████████| 7/7 [00:08<00:00,  1.28s/it, Dice_loss - 0.5493, fscore - 0.9417]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.79it/s, Dice_loss - 0.704, fscore - 0.296]
# Model saved!
#
#  ############## Epoch: 55 , lr: 0.005
# train: 100%|██████████| 7/7 [00:08<00:00,  1.22s/it, Dice_loss - 0.5466, fscore - 0.9501]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.60it/s, Dice_loss - 0.7165, fscore - 0.2836]
#
#  ############## Epoch: 56 , lr: 0.005
# train: 100%|██████████| 7/7 [00:08<00:00,  1.25s/it, Dice_loss - 0.549, fscore - 0.9465]
# valid: 100%|██████████| 6/6 [00:01<00:00,  5.63it/s, Dice_loss - 0.6996, fscore - 0.3007]
# Model saved!
#
#  ############## Epoch: 57 , lr: 0.005
# train: 100%|██████████| 7/7 [00:09<00:00,  1.37s/it, Dice_loss - 0.5652, fscore - 0.9239]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.68it/s, Dice_loss - 0.6956, fscore - 0.3048]
# Model saved!
#
#  ############## Epoch: 58 , lr: 0.005
# train: 100%|██████████| 7/7 [00:09<00:00,  1.29s/it, Dice_loss - 0.5515, fscore - 0.9615]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.72it/s, Dice_loss - 0.7065, fscore - 0.2935]
#
#  ############## Epoch: 59 , lr: 0.005
# train: 100%|██████████| 7/7 [00:09<00:00,  1.30s/it, Dice_loss - 0.542, fscore - 0.9519]
# valid: 100%|██████████| 6/6 [00:01<00:00,  5.27it/s, Dice_loss - 0.7395, fscore - 0.2606]
#
#  ############## Epoch: 60 , lr: 0.005
# train: 100%|██████████| 7/7 [00:10<00:00,  1.44s/it, Dice_loss - 0.5439, fscore - 0.9723]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.87it/s, Dice_loss - 0.7058, fscore - 0.2951]
#
#  ############## Epoch: 61 , lr: 0.005
# train: 100%|██████████| 7/7 [00:09<00:00,  1.39s/it, Dice_loss - 0.5381, fscore - 1.007]
# valid: 100%|██████████| 6/6 [00:00<00:00,  6.64it/s, Dice_loss - 0.7214, fscore - 0.2795]
#
#  ############## Epoch: 62 , lr: 0.005
# ...
#
#  ############## Epoch: 80 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:09<00:00,  1.34s/it, Dice_loss - 0.513, fscore - 0.9974]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.89it/s, Dice_loss - 0.6639, fscore - 0.3358]
#
#  ############## Epoch: 81 , lr: 0.0025
# train: 100%|██████████| 7/7 [00:09<00:00,  1.31s/it, Dice_loss - 0.5237, fscore - 0.9777]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.91it/s, Dice_loss - 0.6739, fscore - 0.3264]
# Loading best model weights!
#
#  ############## Epoch: 82 , lr: 0.00125
# train: 100%|██████████| 7/7 [00:10<00:00,  1.45s/it, Dice_loss - 0.5434, fscore - 0.9911]
# valid: 100%|██████████| 5/5 [00:01<00:00,  4.73it/s, Dice_loss - 0.644, fscore - 0.3567]
# Model saved!
#
#  ############## Epoch: 83 , lr: 0.00125
# train: 100%|██████████| 7/7 [00:09<00:00,  1.35s/it, Dice_loss - 0.5396, fscore - 0.9787]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.98it/s, Dice_loss - 0.6596, fscore - 0.3412]
#
#  ############## Epoch: 84 , lr: 0.00125
# train: 100%|██████████| 7/7 [00:09<00:00,  1.32s/it, Dice_loss - 0.5354, fscore - 0.9776]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.81it/s, Dice_loss - 0.664, fscore - 0.3363]
#
#  ############## Epoch: 85 , lr: 0.00125
# train: 100%|██████████| 7/7 [00:09<00:00,  1.42s/it, Dice_loss - 0.5181, fscore - 0.982]
# valid: 100%|██████████| 5/5 [00:01<00:00,  4.40it/s, Dice_loss - 0.6763, fscore - 0.3242]
#
#  ############## Epoch: 86 , lr: 0.00125
# train: 100%|██████████| 7/7 [00:09<00:00,  1.42s/it, Dice_loss - 0.5364, fscore - 0.9521]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.99it/s, Dice_loss - 0.6704, fscore - 0.3298]
#
#  ############## Epoch: 87 , lr: 0.00125
# train: 100%|██████████| 7/7 [00:08<00:00,  1.26s/it, Dice_loss - 0.5475, fscore - 0.982]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.87it/s, Dice_loss - 0.6641, fscore - 0.3364]
#
#  ############## Epoch: 88 , lr: 0.00125
# train: 100%|██████████| 7/7 [00:08<00:00,  1.22s/it, Dice_loss - 0.5458, fscore - 0.9656]
# valid: 100%|██████████| 5/5 [00:01<00:00,  4.79it/s, Dice_loss - 0.653, fscore - 0.3476]
#
#  ############## Epoch: 89 , lr: 0.00125
# train: 100%|██████████| 7/7 [00:10<00:00,  1.45s/it, Dice_loss - 0.5268, fscore - 0.9862]
# valid: 100%|██████████| 5/5 [00:00<00:00,  5.68it/s, Dice_loss - 0.6519, fscore - 0.3485]
#
#  ############## Epoch: 90 , lr: 0.00125
# train: 100%|██████████| 7/7 [00:09<00:00,  1.29s/it, Dice_loss - 0.525, fscore - 0.985]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.76it/s, Dice_loss - 0.6567, fscore - 0.3431]
#
#  ############## Epoch: 91 , lr: 0.00125
# train: 100%|██████████| 7/7 [00:08<00:00,  1.27s/it, Dice_loss - 0.5355, fscore - 0.9641]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.75it/s, Dice_loss - 0.6662, fscore - 0.3339]
#
#  ############## Epoch: 92 , lr: 0.00125
# train: 100%|██████████| 7/7 [00:09<00:00,  1.40s/it, Dice_loss - 0.5253, fscore - 0.9847]
# valid: 100%|██████████| 5/5 [00:00<00:00,  5.02it/s, Dice_loss - 0.6601, fscore - 0.3399]
#
#  ############## Epoch: 93 , lr: 0.00125
# train: 100%|██████████| 7/7 [00:10<00:00,  1.46s/it, Dice_loss - 0.5112, fscore - 1.023]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.77it/s, Dice_loss - 0.6521, fscore - 0.3486]
# Loading best model weights!
#
#  ############## Epoch: 94 , lr: 0.000625
# train: 100%|██████████| 7/7 [00:09<00:00,  1.32s/it, Dice_loss - 0.5408, fscore - 0.9859]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.92it/s, Dice_loss - 0.6378, fscore - 0.3623]
# Model saved!
#
#  ############## Epoch: 95 , lr: 0.000625
# train: 100%|██████████| 7/7 [00:09<00:00,  1.37s/it, Dice_loss - 0.5381, fscore - 1.008]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.85it/s, Dice_loss - 0.6401, fscore - 0.3598]
#
#  ############## Epoch: 96 , lr: 0.000625
# train: 100%|██████████| 7/7 [00:10<00:00,  1.44s/it, Dice_loss - 0.5355, fscore - 0.9758]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.85it/s, Dice_loss - 0.6411, fscore - 0.3592]
#
#  ############## Epoch: 97 , lr: 0.000625
# train: 100%|██████████| 7/7 [00:09<00:00,  1.31s/it, Dice_loss - 0.5317, fscore - 0.9884]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.87it/s, Dice_loss - 0.6381, fscore - 0.3622]
#
#  ############## Epoch: 98 , lr: 0.000625
# train: 100%|██████████| 7/7 [00:09<00:00,  1.36s/it, Dice_loss - 0.5234, fscore - 0.9915]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.83it/s, Dice_loss - 0.6387, fscore - 0.3612]
#
#  ############## Epoch: 99 , lr: 0.000625
# train: 100%|██████████| 7/7 [00:10<00:00,  1.45s/it, Dice_loss - 0.5329, fscore - 0.9868]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.96it/s, Dice_loss - 0.6393, fscore - 0.3611]
#
#  ############## Epoch: 100 , lr: 0.000625
# train: 100%|██████████| 7/7 [00:08<00:00,  1.27s/it, Dice_loss - 0.5318, fscore - 0.9515]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.74it/s, Dice_loss - 0.6439, fscore - 0.3562]
#
#  ############## Epoch: 101 , lr: 0.000625
# train: 100%|██████████| 7/7 [00:09<00:00,  1.36s/it, Dice_loss - 0.5229, fscore - 0.963]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.91it/s, Dice_loss - 0.6437, fscore - 0.3567]
#
#  ############## Epoch: 102 , lr: 0.000625
# train: 100%|██████████| 7/7 [00:09<00:00,  1.29s/it, Dice_loss - 0.5385, fscore - 0.9531]
# valid: 100%|██████████| 5/5 [00:00<00:00,  5.21it/s, Dice_loss - 0.643, fscore - 0.3576]
#
#  ############## Epoch: 103 , lr: 0.000625
# train: 100%|██████████| 7/7 [00:10<00:00,  1.48s/it, Dice_loss - 0.5194, fscore - 0.9815]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.83it/s, Dice_loss - 0.6487, fscore - 0.3521]
#
#  ############## Epoch: 104 , lr: 0.000625
# train: 100%|██████████| 7/7 [00:09<00:00,  1.39s/it, Dice_loss - 0.5204, fscore - 1.005]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.66it/s, Dice_loss - 0.6513, fscore - 0.348]
#
#  ############## Epoch: 105 , lr: 0.000625
# train: 100%|██████████| 7/7 [00:08<00:00,  1.25s/it, Dice_loss - 0.5427, fscore - 0.9481]
# valid: 100%|██████████| 5/5 [00:00<00:00,  5.69it/s, Dice_loss - 0.6536, fscore - 0.3467]
# Loading best model weights!
#
#  ############## Epoch: 106 , lr: 0.0003125
# train: 100%|██████████| 7/7 [00:09<00:00,  1.43s/it, Dice_loss - 0.5315, fscore - 1.009]
# valid: 100%|██████████| 5/5 [00:00<00:00,  5.70it/s, Dice_loss - 0.6374, fscore - 0.363]
# Model saved!
#
#  ############## Epoch: 107 , lr: 0.0003125
# train: 100%|██████████| 7/7 [00:09<00:00,  1.33s/it, Dice_loss - 0.538, fscore - 0.9643]
# valid: 100%|██████████| 5/5 [00:00<00:00,  5.77it/s, Dice_loss - 0.6375, fscore - 0.3626]
#
#  ############## Epoch: 108 , lr: 0.0003125
# train: 100%|██████████| 7/7 [00:09<00:00,  1.36s/it, Dice_loss - 0.5446, fscore - 0.9745]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.68it/s, Dice_loss - 0.637, fscore - 0.3631]
# Model saved!
#
#  ############## Epoch: 109 , lr: 0.0003125
# train: 100%|██████████| 7/7 [00:10<00:00,  1.47s/it, Dice_loss - 0.5407, fscore - 0.965]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.82it/s, Dice_loss - 0.6359, fscore - 0.3643]
# Model saved!
#
#  ############## Epoch: 110 , lr: 0.0003125
# train: 100%|██████████| 7/7 [00:09<00:00,  1.40s/it, Dice_loss - 0.526, fscore - 1.014]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.60it/s, Dice_loss - 0.6376, fscore - 0.3627]
#
#  ############## Epoch: 111 , lr: 0.0003125
# train: 100%|██████████| 7/7 [00:09<00:00,  1.33s/it, Dice_loss - 0.5296, fscore - 0.9805]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.83it/s, Dice_loss - 0.6398, fscore - 0.3604]
#
#  ############## Epoch: 112 , lr: 0.0003125
# train: 100%|██████████| 7/7 [00:10<00:00,  1.44s/it, Dice_loss - 0.5231, fscore - 0.9995]
# valid: 100%|██████████| 5/5 [00:00<00:00,  5.27it/s, Dice_loss - 0.6422, fscore - 0.3573]
#
#  ############## Epoch: 113 , lr: 0.0003125
# train: 100%|██████████| 7/7 [00:10<00:00,  1.47s/it, Dice_loss - 0.5287, fscore - 0.9667]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.95it/s, Dice_loss - 0.6437, fscore - 0.3559]
#
#  ############## Epoch: 114 , lr: 0.0003125
# train: 100%|██████████| 7/7 [00:09<00:00,  1.30s/it, Dice_loss - 0.5296, fscore - 0.9754]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.68it/s, Dice_loss - 0.6437, fscore - 0.3559]
#
#  ############## Epoch: 115 , lr: 0.0003125
# train: 100%|██████████| 7/7 [00:08<00:00,  1.28s/it, Dice_loss - 0.5338, fscore - 0.9578]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.43it/s, Dice_loss - 0.6403, fscore - 0.3597]
#
#  ############## Epoch: 116 , lr: 0.0003125
# train: 100%|██████████| 7/7 [00:10<00:00,  1.54s/it, Dice_loss - 0.5241, fscore - 0.9858]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.89it/s, Dice_loss - 0.639, fscore - 0.3611]
#
#  ############## Epoch: 117 , lr: 0.0003125
# train: 100%|██████████| 7/7 [00:08<00:00,  1.23s/it, Dice_loss - 0.532, fscore - 0.9782]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.85it/s, Dice_loss - 0.6389, fscore - 0.3613]
#
#  ############## Epoch: 118 , lr: 0.0003125
# train: 100%|██████████| 7/7 [00:09<00:00,  1.31s/it, Dice_loss - 0.5453, fscore - 0.9383]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.81it/s, Dice_loss - 0.6378, fscore - 0.3623]
#
#  ############## Epoch: 119 , lr: 0.0003125
# train: 100%|██████████| 7/7 [00:10<00:00,  1.48s/it, Dice_loss - 0.511, fscore - 1.005]
# valid: 100%|██████████| 5/5 [00:00<00:00,  5.40it/s, Dice_loss - 0.6393, fscore - 0.3614]
#
#  ############## Epoch: 120 , lr: 0.0003125
# train: 100%|██████████| 7/7 [00:09<00:00,  1.34s/it, Dice_loss - 0.533, fscore - 0.9745]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.86it/s, Dice_loss - 0.6389, fscore - 0.3617]
# Loading best model weights!
#
#  ############## Epoch: 121 , lr: 0.00015625
# train: 100%|██████████| 7/7 [00:08<00:00,  1.28s/it, Dice_loss - 0.5459, fscore - 0.9498]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.72it/s, Dice_loss - 0.6333, fscore - 0.3666]
# Model saved!
#
#  ############## Epoch: 122 , lr: 0.00015625
# train: 100%|██████████| 7/7 [00:09<00:00,  1.36s/it, Dice_loss - 0.5521, fscore - 0.9755]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.46it/s, Dice_loss - 0.6317, fscore - 0.3686]
# Model saved!
#
#  ############## Epoch: 123 , lr: 0.00015625
# train: 100%|██████████| 7/7 [00:10<00:00,  1.47s/it, Dice_loss - 0.5271, fscore - 0.9834]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.81it/s, Dice_loss - 0.6337, fscore - 0.3668]
#
#  ############## Epoch: 124 , lr: 0.00015625
# train: 100%|██████████| 7/7 [00:08<00:00,  1.27s/it, Dice_loss - 0.5419, fscore - 0.9622]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.61it/s, Dice_loss - 0.6321, fscore - 0.3678]
#
#  ############## Epoch: 125 , lr: 0.00015625
# train: 100%|██████████| 7/7 [00:09<00:00,  1.35s/it, Dice_loss - 0.5346, fscore - 0.9734]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.97it/s, Dice_loss - 0.6336, fscore - 0.3663]
#
#  ############## Epoch: 126 , lr: 0.00015625
# train: 100%|██████████| 7/7 [00:10<00:00,  1.46s/it, Dice_loss - 0.534, fscore - 0.9816]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.87it/s, Dice_loss - 0.6339, fscore - 0.3661]
#
#  ############## Epoch: 127 , lr: 0.00015625
# train: 100%|██████████| 7/7 [00:09<00:00,  1.30s/it, Dice_loss - 0.5319, fscore - 0.9746]
# valid: 100%|██████████| 5/5 [00:00<00:00,  5.38it/s, Dice_loss - 0.6354, fscore - 0.3641]
#
#  ############## Epoch: 128 , lr: 0.00015625
# train: 100%|██████████| 7/7 [00:09<00:00,  1.33s/it, Dice_loss - 0.5345, fscore - 0.9643]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.92it/s, Dice_loss - 0.6356, fscore - 0.3647]
#
#  ############## Epoch: 129 , lr: 0.00015625
# train: 100%|██████████| 7/7 [00:09<00:00,  1.39s/it, Dice_loss - 0.5365, fscore - 0.9937]
# valid: 100%|██████████| 5/5 [00:00<00:00,  5.51it/s, Dice_loss - 0.6361, fscore - 0.3639]
#
#  ############## Epoch: 130 , lr: 0.00015625
# train: 100%|██████████| 7/7 [00:09<00:00,  1.39s/it, Dice_loss - 0.5228, fscore - 1.003]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.79it/s, Dice_loss - 0.6375, fscore - 0.3625]
#
#  ############## Epoch: 131 , lr: 0.00015625
# train: 100%|██████████| 7/7 [00:09<00:00,  1.38s/it, Dice_loss - 0.5286, fscore - 0.976]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.74it/s, Dice_loss - 0.6384, fscore - 0.3617]
#
#  ############## Epoch: 132 , lr: 0.00015625
# train: 100%|██████████| 7/7 [00:08<00:00,  1.28s/it, Dice_loss - 0.5369, fscore - 0.9709]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.40it/s, Dice_loss - 0.6373, fscore - 0.363]
#
#  ############## Epoch: 133 , lr: 0.00015625
# train: 100%|██████████| 7/7 [00:10<00:00,  1.50s/it, Dice_loss - 0.5176, fscore - 1.003]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.76it/s, Dice_loss - 0.6391, fscore - 0.3606]
# Loading best model weights!
#
#  ############## Epoch: 134 , lr: 7.8125e-05
# train: 100%|██████████| 7/7 [00:09<00:00,  1.38s/it, Dice_loss - 0.5271, fscore - 1.009]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.87it/s, Dice_loss - 0.6329, fscore - 0.3674]
#
#  ############## Epoch: 135 , lr: 7.8125e-05
# train: 100%|██████████| 7/7 [00:09<00:00,  1.39s/it, Dice_loss - 0.5204, fscore - 1.003]
# valid: 100%|██████████| 5/5 [00:00<00:00,  5.78it/s, Dice_loss - 0.6332, fscore - 0.3665]
#
#  ############## Epoch: 136 , lr: 7.8125e-05
# train: 100%|██████████| 7/7 [00:10<00:00,  1.53s/it, Dice_loss - 0.5249, fscore - 0.9814]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.76it/s, Dice_loss - 0.6328, fscore - 0.367]
#
#  ############## Epoch: 137 , lr: 7.8125e-05
# train: 100%|██████████| 7/7 [00:09<00:00,  1.33s/it, Dice_loss - 0.5318, fscore - 0.9745]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.54it/s, Dice_loss - 0.6318, fscore - 0.3681]
#
#  ############## Epoch: 138 , lr: 7.8125e-05
# train: 100%|██████████| 7/7 [00:09<00:00,  1.32s/it, Dice_loss - 0.5231, fscore - 0.9898]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.59it/s, Dice_loss - 0.6322, fscore - 0.368]
#
#  ############## Epoch: 139 , lr: 7.8125e-05
# train: 100%|██████████| 7/7 [00:10<00:00,  1.49s/it, Dice_loss - 0.5258, fscore - 0.9977]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.62it/s, Dice_loss - 0.6311, fscore - 0.3689]
# Model saved!
#
#  ############## Epoch: 140 , lr: 7.8125e-05
# train: 100%|██████████| 7/7 [00:09<00:00,  1.34s/it, Dice_loss - 0.531, fscore - 0.9792]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.91it/s, Dice_loss - 0.631, fscore - 0.3687]
# Model saved!
#
#  ############## Epoch: 141 , lr: 7.8125e-05
# train: 100%|██████████| 7/7 [00:09<00:00,  1.30s/it, Dice_loss - 0.5302, fscore - 0.9725]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.69it/s, Dice_loss - 0.6305, fscore - 0.3694]
# Model saved!
#
#  ############## Epoch: 142 , lr: 7.8125e-05
# train: 100%|██████████| 7/7 [00:09<00:00,  1.38s/it, Dice_loss - 0.5269, fscore - 0.9991]
# valid: 100%|██████████| 5/5 [00:00<00:00,  5.31it/s, Dice_loss - 0.631, fscore - 0.3695]
#
#  ############## Epoch: 143 , lr: 7.8125e-05
# train: 100%|██████████| 7/7 [00:09<00:00,  1.37s/it, Dice_loss - 0.5297, fscore - 0.9866]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.63it/s, Dice_loss - 0.6296, fscore - 0.3705]
# Model saved!
#
#  ############## Epoch: 144 , lr: 7.8125e-05
# train: 100%|██████████| 7/7 [00:09<00:00,  1.36s/it, Dice_loss - 0.5217, fscore - 1.007]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.75it/s, Dice_loss - 0.629, fscore - 0.3712]
# Model saved!
#
#  ############## Epoch: 145 , lr: 7.8125e-05
# train: 100%|██████████| 7/7 [00:09<00:00,  1.32s/it, Dice_loss - 0.5291, fscore - 0.9788]
# valid: 100%|██████████| 5/5 [00:00<00:00,  5.44it/s, Dice_loss - 0.6297, fscore - 0.3705]
#
#  ############## Epoch: 146 , lr: 7.8125e-05
# train: 100%|██████████| 7/7 [00:10<00:00,  1.50s/it, Dice_loss - 0.5359, fscore - 0.9735]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.90it/s, Dice_loss - 0.6303, fscore - 0.3704]
#
#  ############## Epoch: 147 , lr: 7.8125e-05
# train: 100%|██████████| 7/7 [00:08<00:00,  1.28s/it, Dice_loss - 0.5333, fscore - 0.9713]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.90it/s, Dice_loss - 0.6305, fscore - 0.3697]
#
#  ############## Epoch: 148 , lr: 7.8125e-05
# train: 100%|██████████| 7/7 [00:09<00:00,  1.33s/it, Dice_loss - 0.5278, fscore - 0.9963]
# valid: 100%|██████████| 5/5 [00:00<00:00,  5.34it/s, Dice_loss - 0.6321, fscore - 0.3683]
#
#  ############## Epoch: 149 , lr: 7.8125e-05
# train: 100%|██████████| 7/7 [00:10<00:00,  1.56s/it, Dice_loss - 0.5212, fscore - 1.006]
# valid: 100%|██████████| 5/5 [00:00<00:00,  6.80it/s, Dice_loss - 0.6336, fscore - 0.3667]
# f1-score:  0.3712126678463891
# Ensemble F1 score : 0.3383179958443663

# %% [markdown]
# ### Data Inferences

# %%
te_img_path = f"/kaggle/input/nasaharvest/{dataset_id}/{dataset_id}_source_test/{dataset_id}_source_test"

test_tiles = [clean_string(s) for s in next(os.walk(te_img_path))[1]]

te_tiles_id = list(np.unique([int(te_id.split("_")[0]) for te_id in test_tiles]))

te_tiles_id = [f"{number:02d}" for number in te_tiles_id]

# %%
test_dataset = Dataset(
    te_tiles_id,
    te_img_path,
    masks_dir=None,
    augmentation=None,
    data_type='test',
)

test_dataloader = DataLoader(test_dataset, batch_size=1, shuffle=False)

# %%
predictions_dictionary = {}
for i, (xb, _) in enumerate(test_dataloader):
    ens_pr_mask = np.zeros((256,256))
    for m in range(10):
        model.load_state_dict(torch.load(f'./best_model_{m+1}.pth'))

        masks = []
        mask1 = model.predict(xb.cuda())
        mask1 = mask1.squeeze().detach().cpu().numpy()
        masks.append(mask1)
        pr_mask = np.mean(masks, axis=0)
        ens_pr_mask+=mask1
    pr_mask = ens_pr_mask/10
    pr_mask = np.where(pr_mask>=0.5,1, 0 )
    predictions_dictionary.update([(str(te_tiles_id[i]), pd.DataFrame(pr_mask))])

# %%
dfs = []
for key, value in predictions_dictionary.items():
    ftd = value.unstack().reset_index().rename(columns={'level_0': 'row', 'level_1': 'column', 0: 'label'})
    ftd['tile_row_column'] = f'Tile{key}_' + ftd['row'].astype(str) + '_' + ftd['column'].astype(str)
    ftd = ftd[['tile_row_column', 'label']]
    dfs.append(ftd)

sub = pd.concat(dfs)
sub
# Out:
#       tile_row_column  label
# 0          Tile00_0_0      0
# 1          Tile00_0_1      0
# 2          Tile00_0_2      0
# 3          Tile00_0_3      0
# 4          Tile00_0_4      0
# ...               ...    ...
# 65531  Tile12_255_251      0
# 65532  Tile12_255_252      0
# 65533  Tile12_255_253      0
# 65534  Tile12_255_254      0
# 65535  Tile12_255_255      0
#
# [851968 rows x 2 columns]

# %%
sub['label'] = sub['label'].astype('int')
sub.to_csv(f"./submission.csv", index = False)
